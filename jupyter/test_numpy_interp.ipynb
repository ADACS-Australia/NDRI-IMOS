# %%
## Demonstrating numpy.interp() function

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

### Basic Usage of numpy.interp()

# Define known x and y values
x = np.array([0, 1, 2, 3, 4, 5])
y = np.array([0, 2, 4, 6, 8, 10])

# Define x values to interpolate
x_interp = np.linspace(0, 5, 50)

# Perform interpolation
y_interp = np.interp(x_interp, x, y)

# Plot the results
plt.figure(figsize=(10, 6))
plt.plot(x, y, 'ro-', label='Original data')
plt.plot(x_interp, y_interp, 'b-', label='Interpolated data')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Basic numpy.interp() example')
plt.legend()
plt.grid(True)
plt.show()

# %%
calSpecInt = np.array([0, 1, 2, 3, 4, 5])

print(calSpecInt[0:-1])
print(calSpecInt[::-1][:-1])
import numpy
what = numpy.sqrt(numpy.concatenate((calSpecInt[0:-1], calSpecInt[::-1][:-1])))
print(what)
# Out:
# [0 1 2 3 4]
# [5 4 3 2 1]
# [0.         1.         1.41421356 1.73205081 2.         2.23606798
#  2.         1.73205081 1.41421356 1.        ]

# %%
calSpecInt = np.array([0, 1, 2, 3, 4])
print(calSpecInt[::-1][:-1])
# Out:
# [4 3 2 1]

# %%
print(calSpecInt[0:3])
print(calSpecInt[-3:][::-1])
# Out:
# [0 1 2]
# [4 3 2]
